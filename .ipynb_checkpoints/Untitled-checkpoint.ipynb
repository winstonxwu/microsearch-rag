# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from langchain_brightdata import BrightDataSERP
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.prebuilt import create_react_agent
from dotenv import load_dotenv
import os

load_dotenv()

print("Environmental setup complete!")
print(f"Bright Data API Key loaded: {'Yes' if os.getenv('BRIGHT_DATA_API_TOKEN') else 'No'}")
print(f"Google API Key loaded: {'Yes' if os.getenv('GOOGLE_API_KEY') else 'No'}")
# Importing the libraries
# Out:
# Environmental setup complete!
# Bright Data API Key loaded: Yes
# Google API Key loaded: Yes

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.1
)

print("Language model initialized successfully!")
# Initializing the LLM
# Out:
# Language model initialized successfully!

# %%
serp_tool = BrightDataSERP(
    search_engine="google",
    country="us",
    language="en",
    results_count=10,
    parse_results=True,
)

print("Bright Data SERP tool configured successfully!")
print(f"Search Engine: {serp_tool.search_engine}")
print(f"Country: {serp_tool.country}")
print(f"Language: {serp_tool.language}")
print(f"Results Count: {serp_tool.results_count}")
# Out:
# Bright Data SERP tool configured successfully!
# Search Engine: google
# Country: us
# Language: en
# Results Count: 10

# %%
agent = create_react_agent(
    model=llm,
    tools=[serp_tool],
    prompt="""You are a web researcher agent with access to SERP tool, you will HAVE to use the user query, if no specific, country, language, search engine or specific vertical, choose what's best fit users questions""",
)

print("ReAct Web Scraper Agent created successfully!")
print("Agent is ready to search and analyze web content!")
# Out:
# ReAct Web Scraper Agent created successfully!
# Agent is ready to search and analyze web content!

# %%
print("Basic Testing Search ...")
print("="*50)

user_query = "What are the latest developments and news in AI technology in the US?"

for step in agent.stream(
    {"messages": [("human", user_query)]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# Basic Testing Search ...
# ==================================================
# ================================ Human Message =================================
#
# What are the latest developments and news in AI technology in the US?
# ================================== Ai Message ==================================
# Tool Calls:
#   brightdata_serp (379ac9f4-b819-4d4b-97ac-57a9aad8b663)
#  Call ID: 379ac9f4-b819-4d4b-97ac-57a9aad8b663
#   Args:
#     country: us
#     search_type: nws
#     query: latest developments and news in AI technology
# https://api.brightdata.com/request {'zone': 'serp', 'url': 'https://www.google.com/search?q=latest%20developments%20and%20news%20in%20AI%20technology&gl=us&hl=en&num=10&brd_json=1&tbm=nws', 'format': 'raw'} {'Authorization': 'Bearer 96a9d804bb52f4e3bf2280b1d138a04a4442d1ebc413dd2b22aa7cd299c62624', 'Content-Type': 'application/json'}
# ================================= Tool Message =================================
# Name: brightdata_serp
#
# {"general":{"search_engine":"google","query":"latest developments and news in AI technology","results_cnt":14100000,"search_time":0.27,"language":"en","location":"United States","mobile":false,"basic_view":false,"search_type":"news","page_title":"latest developments and news in AI technology - Google Search","timestamp":"2025-08-27T21:46:04.443Z"},"input":{"original_url":"https://www.google.com/search?q=latest+developments+and+news+in+AI+technology&gl=us&hl=en&num=10&brd_json=1&tbm=nws","request_id":"hl_460524f6_5ixstqh5nyp"},"navigation":[{"title":"All","href":"https://www.google.com/search?q=latest+developments+and+news+in+AI+technology&sca_esv=ba24c2d2484ecd3d&gl=us&hl=en&source=lnms&sa=X&ved=2ahUKEwj52r24-6uPAxUtUGwGHcswKKQQ0pQJegQIAhAD"},{"title":"Images","href":"https://www.google.com/search?q=latest+developments+and+news+in+AI+technology&sca_esv=ba24c2d2484ecd3d&gl=us&hl=en&udm=2&source=lnms&sa=X&ved=2ahUKEwj52r24-6uPAxUtUGwGHcswKKQQ0pQJegQIAhAF"},{"title":"Videos","href":"https://www.google.com/search?q=latest+developments+and+news+in+AI+technology&sca_esv=ba24c2d2484ecd3d&gl=us&hl=en&udm=7&source=lnms&sa=X&ved=2ahUKEwj52r24-6uPAxUtUGwGHcswKKQQ0pQJegQIAhAH"},{"title":"Shopping","href":"https://www.google.com/search?q=latest+developments+and+news+in+AI+technology&sca_esv=ba24c2d2484ecd3d&gl=us&hl=en&udm=28&source=lnms&ved=1t:200715&ictx=111"},{"title":"Books","href":"https://www.google.com/search?q=latest+developments+and+news+in+AI+technology&sca_esv=ba24c2d2484ecd3d&gl=us&hl=en&udm=36&source=lnms&sa=X&ved=2ahUKEwj52r24-6uPAxUtUGwGHcswKKQQ0pQJegQIAhAN"},{"title":"Maps","href":"https://maps.google.com/maps?q=latest+developments+and+news+in+AI+technology&gl=us&hl=en&num=10&um=1&ie=UTF-8&ved=1t:200715&ictx=111"}],"news":[{"title":"Emerging technology trends brands and agencies need to know about right now","link":"https://adage.com/technology/ai/aa-emerging-tech-news-for-brands-and-agencies-aug-27-2025/","source":"Ad Age","source_logo":"data:image/png;base64,...","description":"Welcome to Ad Age's emerging technology news roundup. Each week, we'll be highlighting the latest news at the intersection between marketing...","date":"13 hours ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":1,"global_rank":1},{"title":"AI News: Artificial Intelligence Trends And Top AI Stocks To Watch","link":"https://www.investors.com/news/technology/ai-stocks-artificial-intelligence-trends-and-news/","source":"Investor's Business Daily","source_logo":"data:image/png;base64,...","description":"What is artificial intelligence? And what are the best AI stocks to buy and watch? Track the trend leaders beyond just Nvidia.","date":"2 days ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":2,"global_rank":2},{"title":"Tech Newsflash","link":"https://www.whitecase.com/insight-our-thinking/tech-newsflash","source":"White & Case LLP","source_logo":"...","description":"The White & Case Tech Newsflash provides updates on the latest issues and trends in technology and the law. We deliver fresh perspectives across all of our...","date":"1 week ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":3,"global_rank":3},{"title":"The latest AI news we announced in June","link":"https://blog.google/technology/ai/google-ai-updates-june-2025/","source":"The Keyword","source_logo":"data:image/png;base64,...","description":"Here's a recap of some of our biggest AI updates from June, including more ways to search with AI Mode, a new way to share your NotebookLM notebooks publicly.","date":"Jul 2, 2025","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":4,"global_rank":4},{"title":"Amazon announces 3 AI-powered innovations to get packages to customers faster","link":"https://www.aboutamazon.com/news/operations/amazon-ai-innovations-delivery-forecasting-robotics","source":"About Amazon","source_logo":"...","de ...
# ================================== Ai Message ==================================
#
# Here's a summary of the latest AI developments and news in the US, based on the search results:
#
# *   **AI in Marketing and Emerging Technologies:** Ad Age highlights emerging technology trends for brands and agencies, focusing on the intersection of marketing and AI.
# *   **AI Stocks and Trends:** Investor's Business Daily tracks AI stocks and trends, identifying leaders beyond just Nvidia.
# *   **AI and the Law:** White & Case Tech Newsflash provides updates on the latest issues and trends in technology and the law, including AI.
# *   **Google AI Updates:** The Keyword, Google's official blog, recaps AI updates from June 2025, including new ways to search with AI Mode and share NotebookLM notebooks publicly.
# *   **Amazon's AI Innovations:** About Amazon discusses AI-powered innovations to improve delivery speed and forecasting.
# *   **Google AI Search:** CBS News explains Google's new AI search technology, AI Mode, designed to provide more detailed and tailored responses.
# *   **McKinsey Technology Trends Outlook:** McKinsey & Company provides an annual analysis ranking the top tech trends, including AI.
# *   **AI Chips for Defense:** Yahoo Finance reports on Lantronix's advancements in AI chips for defense, providing a TAA and NDAA-compliant solution for Teal Drones.
# *   **Deepseek in the AI Landscape:** Georgia State University News discusses how Deepseek, a Chinese start-up, is impacting the AI landscape.
# *   **AI in Everyday Life:** BBC discusses how AI has become part of everyday life and addresses concerns about apps like ChatGPT.

# %%
print("Basic Testing Search ...")
print("="*50)

user_query = "What is the latest news in Geopolitics?"

for step in agent.stream(
    {"messages": [("human", user_query)]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# Basic Testing Search ...
# ==================================================
# ================================ Human Message =================================
#
# What is the latest news in Geopolitics?
# ================================== Ai Message ==================================
# Tool Calls:
#   brightdata_serp (5380fa8c-c2e3-4eac-ac12-b0af451870cf)
#  Call ID: 5380fa8c-c2e3-4eac-ac12-b0af451870cf
#   Args:
#     search_type: nws
#     query: latest news in Geopolitics
# https://api.brightdata.com/request {'zone': 'serp', 'url': 'https://www.google.com/search?q=latest%20news%20in%20Geopolitics&gl=us&hl=en&num=10&brd_json=1&tbm=nws', 'format': 'raw'} {'Authorization': 'Bearer 96a9d804bb52f4e3bf2280b1d138a04a4442d1ebc413dd2b22aa7cd299c62624', 'Content-Type': 'application/json'}
# ================================= Tool Message =================================
# Name: brightdata_serp
#
# {"general":{"search_engine":"google","query":"latest news in Geopolitics","results_cnt":43900,"search_time":0.22,"language":"en","location":"United States","mobile":false,"basic_view":false,"search_type":"news","page_title":"latest news in Geopolitics - Google Search","timestamp":"2025-08-28T12:22:57.151Z"},"input":{"original_url":"https://www.google.com/search?q=latest+news+in+Geopolitics&gl=us&hl=en&num=10&brd_json=1&tbm=nws","request_id":"hl_460524f6_rn2zjfj959"},"navigation":[{"title":"AI Mode","href":"https://www.google.com/search?q=latest+news+in+Geopolitics&sca_esv=f2b4c39e3966b02c&gl=us&hl=en&udm=50&aep=1&ntc=1&sa=X&ved=2ahUKEwjC-7S4v62PAxXcuZUCHcTRAT0Q2J8OegQIAhAD"},{"title":"All","href":"https://www.google.com/search?q=latest+news+in+Geopolitics&sca_esv=f2b4c39e3966b02c&gl=us&hl=en&source=lnms&sa=X&ved=2ahUKEwjC-7S4v62PAxXcuZUCHcTRAT0Q0pQJegQIAhAF"},{"title":"Images","href":"https://www.google.com/search?q=latest+news+in+Geopolitics&sca_esv=f2b4c39e3966b02c&gl=us&hl=en&udm=2&source=lnms&sa=X&ved=2ahUKEwjC-7S4v62PAxXcuZUCHcTRAT0Q0pQJegQIAhAH"},{"title":"Videos","href":"https://www.google.com/search?q=latest+news+in+Geopolitics&sca_esv=f2b4c39e3966b02c&gl=us&hl=en&udm=7&source=lnms&sa=X&ved=2ahUKEwjC-7S4v62PAxXcuZUCHcTRAT0Q0pQJegQIAhAJ"},{"title":"Shopping","href":"https://www.google.com/search?q=latest+news+in+Geopolitics&sca_esv=f2b4c39e3966b02c&gl=us&hl=en&udm=28&source=lnms&ved=1t:200715&ictx=111"},{"title":"Books","href":"https://www.google.com/search?q=latest+news+in+Geopolitics&sca_esv=f2b4c39e3966b02c&gl=us&hl=en&udm=36&source=lnms&sa=X&ved=2ahUKEwjC-7S4v62PAxXcuZUCHcTRAT0Q0pQJegQIAhAP"}],"news":[{"title":"2024 was rough year for geopolitics. Here’s what U.S. is facing.","link":"https://news.harvard.edu/gazette/story/2025/02/2024-was-rough-year-for-geopolitics-heres-what-u-s-is-facing/","source":"Harvard Gazette","source_logo":"...","description":"Former national security official Ben Rhodes surveys global hot spots — and how the new administration's ideas are being received.","date":"Feb 5, 2025","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":1,"global_rank":1},{"title":"Stars and geopolitics share the spotlight at Venice Film Festival | Hollywood - Hindustan Times","link":"https://www.hindustantimes.com/entertainment/hollywood/stars-and-geopolitics-share-the-spotlight-at-venice-film-festival-101756207147543.html","source":"Hindustan Times","source_logo":"data:image/png;base64,...","description":"FILMFESTIVAL-VENICE/DIRECTOR (TV, PIX):Stars and geopolitics share the spotlight at Venice Film Festival | Hollywood.","date":"2 days ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":2,"global_rank":2},{"title":"Anthony Albanese: Trade trumps geopolitics as Australia PM visits China","link":"https://www.bbc.com/news/articles/c7vrjlp5zdvo","source":"BBC","source_logo":"...","description":"Australia's leader Anthony Albanese will visit China and meet with President Xi Jinping this weekend as he seeks to strengthen ties with Canberra's largest...","date":"1 month ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":3,"global_rank":3},{"title":"Global Geopolitics: Why the Russia-India-China Reboot Won’t Last","link":"https://www.deccanherald.com/world/why-the-russia-india-china-reboot-wont-last-3695668","source":"Deccan Herald","source_logo":"...","description":"Asia Diplomacy: Revived to counter US pressure, the Moscow-led RIC bloc faces India-China mistrust, Beijing's Pakistan tilt, and New Delhi's...","date":"3 days ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":4,"global_rank":4},{"title":"Shifting trade flows in Europe: How geopolitical dynamics are shaping new alliances","link":"https://www.deloitte.com/us/en/insights/topics/business-strategy-growth/eu-trade-shifts-geopolitics.html","source":"Deloitte","source_logo":"...","description":"The Deloitt ...
# ================================== Ai Message ==================================
#
# Here's a summary of the latest news in geopolitics:
#
# *   **Harvard Gazette:** 2024 was a rough year for geopolitics, and the article discusses what the U.S. is facing.
# *   **Hindustan Times:** Stars and geopolitics shared the spotlight at the Venice Film Festival.
# *   **BBC:** Australia's leader visited China to strengthen ties, with trade trumping geopolitics.
# *   **Deccan Herald:** Discusses why the Russia-India-China reboot won’t last.
# *   **Deloitte:** The Deloitte geoeconomic dynamics index reveals how Europe's trade partnerships could shift in new geopolitical fragmentation.
# *   **McKinsey & Company:** Discusses how American business can prosper in the new geopolitical era
# *   **Morocco World News:** Geopolitics as an Exact Science
# *   **Bloomberg.com:** New Oil Geopolitics Laid Bare By Iran Conflict
# *   **Columbia University's Center on Global Energy Policy:** Why Trump’s Gulf Tour Matters for Energy, AI, and Geopolitics
# *   **JPMorganChase:** The JPMorganChase Center for Geopolitics is a resource for clients seeking timely analysis and insights on the top global trends.
